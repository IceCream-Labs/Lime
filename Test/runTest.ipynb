# %%
# %cd /mnt/d/Work/lime
# Out:
# /mnt/d/Work/lime

# %%
import pandas as pd

pd.read_excel("./Test/test.xlsx").head(1)
# Out:
#             qtype                                            context  \
# 0  Data Retrieval  Bumble Bee Sensations Seasoned Tuna Pouch, Jal...
#
#                                             question  \
# 0  Based on the information given in the above te...
#
#                                         ground-truth  \
# 0  {"title": "Bumble Bee Sensations Seasoned Tuna...
#
#                                               prompt  \
# 0  The following is a conversation between a cust...
#
#                                             response
# 0  Title: Bumble Bee Sensations Seasoned Tuna Pou...

# %% [markdown]
# # LME Test

# %%
# !python3 lime.py --openai_key "<OPEN_AI_KEY>" \
--testset_path Test/test.xlsx \
--test_type "lme" \
--ground_truth_col "ground-truth" \
--model_response_col "response" \
--query_col "question" \
--context_col "context" \
--test_name "dummyTest"

pd.read_excel("./results/dummyTest.xlsx")
# Out:
# Language Model Evaluation: 100%|████████████████████████████████████████████████
# Saving results to ./results/dummyTest.xlsx
#
#         -----------------------------------------------------
#         |   Language Model Score  |    BiEncoder Score      |
#         -----------------------------------------------------
#         |           59.0    |         NA              |
#         -----------------------------------------------------
#             qtype                                            context  \
# 0  Data Retrieval  Bumble Bee Sensations Seasoned Tuna Pouch, Jal...
# 1  Data Retrieval  Yardley London Moisturizing Bar Oatmeal & Almo...
# 2  Data Retrieval  5 Pack - TruBiotics One-A-Day Probiotic Supple...
# 3  Data Retrieval  Johnson Diversey CB126811 White Travel Size Ba...
# 4  Data Retrieval  HomeoLab Kids Relief Teething Homeopathic Medi...
#
#                                             question  \
# 0  Based on the information given in the above te...
# ...

# %% [markdown]
# # BiEncoder Test

# %%
# !python3 lime.py \
--testset_path Test/test.xlsx \
--test_type "bee" \
--ground_truth_col "ground-truth" \
--model_response_col "response" \
--query_col "question" \
--context_col "context" \
--test_name "dummyTest"

pd.read_excel("./results/dummyTest.xlsx")
# Out:
# BiEncoder Evaluation: 100%|██████████████████████████████████████████████████| 5
# Saving results to ./results/dummyTest.xlsx
#
#         -----------------------------------------------------
#         |   Language Model Score  |    BiEncoder Score      |
#         -----------------------------------------------------
#         |           NA    |         71.735              |
#         -----------------------------------------------------
#             qtype                                            context  \
# 0  Data Retrieval  Bumble Bee Sensations Seasoned Tuna Pouch, Jal...
# 1  Data Retrieval  Yardley London Moisturizing Bar Oatmeal & Almo...
# 2  Data Retrieval  5 Pack - TruBiotics One-A-Day Probiotic Supple...
# 3  Data Retrieval  Johnson Diversey CB126811 White Travel Size Ba...
# 4  Data Retrieval  HomeoLab Kids Relief Teething Homeopathic Medi...
#
#                                             question  \
# 0  Based on the information given in the above te...
# ...

# %% [markdown]
# # All Tests

# %%
# !python3 lime.py --openai_key "<OPEN_AI_KEY>" \
--testset_path Test/test.xlsx \
--test_type "all" \
--ground_truth_col "ground-truth" \
--model_response_col "response" \
--query_col "question" \
--context_col "context" \
--test_name "dummyTest"

pd.read_excel("./results/dummyTest.xlsx")
# Out:
# Language Model Evaluation: 100%|████████████████████████████████████████████████
# BiEncoder Evaluation: 100%|██████████████████████████████████████████████████| 5
# Saving results to ./results/dummyTest.xlsx
#
#         -----------------------------------------------------
#         |   Language Model Score  |    BiEncoder Score      |
#         -----------------------------------------------------
#         |           59.0    |         71.735              |
#         -----------------------------------------------------
#             qtype                                            context  \
# 0  Data Retrieval  Bumble Bee Sensations Seasoned Tuna Pouch, Jal...
# 1  Data Retrieval  Yardley London Moisturizing Bar Oatmeal & Almo...
# 2  Data Retrieval  5 Pack - TruBiotics One-A-Day Probiotic Supple...
# 3  Data Retrieval  Johnson Diversey CB126811 White Travel Size Ba...
# 4  Data Retrieval  HomeoLab Kids Relief Teething Homeopathic Medi...
#
# ...
